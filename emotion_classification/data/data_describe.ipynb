# %%
import pandas as pd

# %%
data = pd.read_csv('simplifyweibo_4_moods.csv')

# %%
data
# Out:
#         label                                             review
# 0           0  ﻿啊呀呀！要死啦！么么么！只穿外套就好了，我认为里面那件很多余啊周小伦喜歡 你各種 五角星的...
# 1           0  嗯……既然大姚通知了……那我也表示下收到……姚，你知道吗？假如外星人入侵地球，只要摧毁我们的...
# 2           0                                  风格不一样嘛，都喜欢！最喜欢哪张？
# 3           0  好呀，试试D .I .Y .去死皮面膜1.将燕麦片加水中浸泡6小时，加入木瓜牛奶搅拌。2.放...
# 4           0  张老师，谢谢侬的信任！粉丝多少无所谓重在质地近日发现一个现象——他加了你关注，你回加后，他立...
# ...       ...                                                ...
# 361739      3                                         德国队就那样输了……
# 361740      3  人也一样,沒 钱沒 地位,谁会关注你?大庆和上海都是被人遗忘的角落，都是被遗弃的孩子。。。当...
# 361741      3                                             巴西要回家啦
# 361742      3  派啦！諗 咩吖 ！撐 呀！十五十六之而家已經 差不多十一月仲派唔派歌好呢?定係 出年先派呢?...
# 361743      3                         发觉呢个期末特别懒～死硬啦死硬啦，我要静心复习啊！！
#
# [361744 rows x 2 columns]

# %%
for i,j in enumerate(data['label']):
    if j in [1,2,3]:
        data['label'][i] = 1
# Out:
# <ipython-input-4-a13b293a95e9>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['label'][i] = 1

# %%
data
# Out:
#         label                                             review
# 0           0  ﻿啊呀呀！要死啦！么么么！只穿外套就好了，我认为里面那件很多余啊周小伦喜歡 你各種 五角星的...
# 1           0  嗯……既然大姚通知了……那我也表示下收到……姚，你知道吗？假如外星人入侵地球，只要摧毁我们的...
# 2           0                                  风格不一样嘛，都喜欢！最喜欢哪张？
# 3           0  好呀，试试D .I .Y .去死皮面膜1.将燕麦片加水中浸泡6小时，加入木瓜牛奶搅拌。2.放...
# 4           0  张老师，谢谢侬的信任！粉丝多少无所谓重在质地近日发现一个现象——他加了你关注，你回加后，他立...
# ...       ...                                                ...
# 361739      1                                         德国队就那样输了……
# 361740      1  人也一样,沒 钱沒 地位,谁会关注你?大庆和上海都是被人遗忘的角落，都是被遗弃的孩子。。。当...
# 361741      1                                             巴西要回家啦
# 361742      1  派啦！諗 咩吖 ！撐 呀！十五十六之而家已經 差不多十一月仲派唔派歌好呢?定係 出年先派呢?...
# 361743      1                         发觉呢个期末特别懒～死硬啦死硬啦，我要静心复习啊！！
#
# [361744 rows x 2 columns]

# %%
data.loc[0, 'review']
# Out:
# '\ufeff啊呀呀！要死啦！么么么！只穿外套就好了，我认为里面那件很多余啊周小伦喜歡 你各種 五角星的項 鏈 和露胸的衣服XD 伦伦啊，你真的是越来越帅了·····'

# %%
sentence_len = []
max_len = 0
for i in data['review']:
    sentence_len.append(len(i))
    if len(i) > max_len:
        max_len = len(i)

# %%
max_len
# Out:
# 419

# %%
sentence_len
# Out:
# [77,
#  96,
#  17,
#  94,
#  79,
#  133,
#  112,
#  109,
#  127,
#  14,
#  53,
#  125,
#  50,
#  11,
#  36,
#  34,
#  71,
#  14,
#  17,
#  42,
#  89,
#  37,
#  10,
#  241,
#  199,
#  166,
#  25,
#  7,
#  66,
#  34,
#  39,
#  50,
#  31,
#  15,
#  73,
#  35,
#  58,
#  155,
#  26,
#  20,
#  40,
#  104,
#  107,
#  137,
#  76,
#  99,
#  51,
#  143,
#  213,
#  186,
#  26,
#  169,
#  20,
#  24,
#  21,
#  91,
#  215,
#  19,
#  138,
#  33,
#  140,
#  14,
#  22,
#  48,
#  72,
#  12,
#  29,
#  43,
#  52,
#  67,
#  96,
#  63,
#  133,
#  25,
#  72,
#  11,
#  203,
#  145,
#  77,
#  214,
#  35,
#  15,
#  150,
#  243,
#  63,
#  102,
#  9,
#  15,
#  52,
#  82,
#  45,
#  52,
#  36,
#  24,
#  48,
#  156,
#  169,
#  65,
#  11,
#  32,
#  16,
#  28,
#  16,
#  33,
#  147,
#  43,
#  24,
#  60,
#  235,
#  101,
#  157,
#  77,
#  80,
#  90,
#  150,
#  56,
#  18,
#  33,
#  74,
#  49,
#  114,
#  41,
#  29,
#  107,
#  23,
#  10,
#  145,
#  73,
#  80,
#  47,
#  30,
#  12,
#  47,
#  44,
#  73,
#  182,
#  80,
#  59,
#  24,
#  97,
#  41,
#  122,
#  124,
#  146,
#  155,
#  38,
#  21,
#  139,
#  147,
#  38,
#  87,
#  18,
#  89,
#  83,
#  162,
#  7,
#  11,
#  73,
#  32,
#  64,
#  32,
#  97,
#  134,
#  23,
#  42,
#  181,
#  71,
#  87,
#  28,
#  107,
#  30,
#  27,
#  64,
#  94,
#  43,
#  45,
#  13,
#  39,
#  72,
#  54,
#  55,
#  67,
#  141,
#  145,
#  8,
#  56,
#  41,
#  25,
#  10,
#  171,
#  90,
#  22,
#  30,
#  61,
#  26,
#  28,
#  107,
#  81,
#  127,
#  118,
#  19,
#  66,
#  24,
#  225,
#  45,
#  62,
#  33,
#  63,
#  160,
#  98,
#  32,
#  100,
#  34,
#  106,
#  101,
#  23,
#  13,
#  40,
#  15,
#  60,
#  60,
#  33,
#  35,
#  12,
#  8,
#  225,
#  127,
#  87,
#  49,
#  98,
#  72,
#  24,
#  25,
#  91,
#  62,
#  95,
#  100,
#  43,
#  20,
#  43,
#  12,
#  39,
#  127,
#  41,
#  92,
#  130,
#  107,
#  90,
#  20,
#  39,
#  44,
#  70,
#  29,
#  33,
#  95,
#  29,
#  14,
#  18,
#  95,
#  41,
#  52,
#  43,
#  30,
#  113,
#  24,
#  50,
#  63,
#  22,
#  7,
#  102,
#  10,
#  139,
#  172,
#  171,
#  80,
#  69,
#  148,
#  129,
#  134,
#  59,
#  66,
#  51,
#  39,
#  72,
#  168,
#  48,
#  61,
#  102,
#  124,
#  53,
#  128,
#  7,
#  78,
#  36,
#  68,
#  48,
#  158,
#  149,
#  36,
#  85,
#  9,
#  130,
#  55,
#  64,
#  193,
#  95,
#  105,
#  33,
#  239,
#  9,
#  123,
#  162,
#  124,
#  45,
#  168,
#  66,
#  50,
#  20,
#  242,
#  30,
#  151,
#  35,
#  18,
#  32,
#  40,
#  64,
#  60,
#  121,
#  90,
#  116,
#  44,
#  49,
#  87,
#  189,
#  146,
#  146,
#  136,
#  28,
#  61,
#  34,
#  53,
#  45,
#  56,
#  64,
#  114,
#  63,
#  102,
#  142,
#  29,
#  146,
#  115,
#  208,
#  14,
#  17,
#  9,
#  143,
#  15,
#  150,
#  121,
#  102,
#  109,
#  59,
#  102,
#  116,
#  152,
#  34,
#  93,
#  83,
#  14,
#  165,
#  16,
#  111,
#  12,
#  18,
#  149,
#  91,
#  182,
#  52,
#  55,
#  27,
#  128,
#  143,
#  36,
#  88,
#  131,
#  27,
#  134,
#  26,
#  17,
#  125,
#  46,
#  55,
#  197,
#  20,
#  33,
#  74,
#  88,
#  13,
#  74,
#  65,
#  57,
#  37,
#  35,
#  25,
#  77,
#  64,
#  25,
#  12,
#  125,
#  15,
#  8,
#  108,
#  123,
#  130,
#  35,
#  46,
#  106,
#  108,
#  112,
#  131,
#  167,
#  195,
#  33,
#  140,
#  37,
#  63,
#  105,
#  17,
#  146,
#  202,
#  131,
#  155,
#  66,
#  94,
#  42,
#  17,
#  116,
#  17,
#  23,
#  43,
#  16,
#  141,
#  164,
#  119,
#  61,
#  145,
#  45,
#  126,
#  92,
#  97,
#  25,
#  41,
#  29,
#  115,
#  14,
#  18,
#  100,
#  46,
#  133,
#  44,
#  42,
#  14,
#  92,
#  31,
#  51,
#  50,
#  124,
#  15,
#  66,
#  72,
#  13,
#  41,
#  23,
#  18,
#  21,
#  106,
#  20,
#  19,
#  124,
#  53,
#  61,
#  37,
#  116,
#  171,
#  175,
#  25,
#  38,
#  130,
#  47,
#  64,
#  111,
#  7,
#  25,
#  52,
#  116,
#  110,
#  100,
#  68,
#  74,
#  65,
#  31,
#  115,
#  31,
#  5,
#  9,
#  56,
#  11,
#  150,
#  84,
#  151,
#  73,
#  63,
#  36,
#  30,
#  48,
#  163,
#  51,
#  116,
#  119,
#  27,
#  143,
#  28,
#  72,
#  11,
#  115,
#  137,
#  42,
#  89,
#  29,
#  43,
#  86,
#  8,
#  146,
#  76,
#  22,
#  31,
#  59,
#  14,
#  13,
#  67,
#  46,
#  22,
#  20,
#  114,
#  12,
#  17,
#  17,
#  25,
#  48,
#  42,
#  33,
#  139,
#  71,
#  105,
#  43,
#  11,
#  23,
#  32,
#  20,
#  172,
#  67,
#  16,
#  109,
#  21,
#  121,
#  68,
#  24,
#  27,
#  12,
#  18,
#  137,
#  132,
#  68,
#  23,
#  75,
#  18,
#  51,
#  82,
#  59,
#  31,
#  88,
#  23,
#  41,
#  42,
#  123,
#  152,
#  142,
#  29,
#  58,
#  26,
#  112,
#  88,
#  90,
#  149,
#  40,
#  20,
#  182,
#  31,
#  12,
#  11,
#  14,
#  127,
#  64,
#  44,
#  51,
#  24,
#  10,
#  138,
#  164,
#  174,
#  179,
#  69,
#  144,
#  13,
#  146,
#  91,
#  20,
#  90,
#  35,
#  15,
#  69,
#  71,
#  85,
#  139,
#  10,
#  28,
#  135,
#  200,
#  31,
#  25,
#  48,
#  149,
#  77,
#  79,
#  116,
#  52,
#  48,
#  14,
#  16,
#  99,
#  53,
#  92,
#  43,
#  33,
#  8,
#  78,
#  103,
#  104,
#  8,
#  68,
#  64,
#  26,
#  182,
#  82,
#  21,
#  35,
#  19,
#  149,
#  25,
#  14,
#  27,
#  53,
#  21,
#  82,
#  18,
#  8,
#  116,
#  50,
#  48,
#  21,
#  112,
#  22,
#  38,
#  69,
#  45,
#  71,
#  111,
#  60,
#  13,
#  50,
#  166,
#  40,
#  24,
#  5,
#  89,
#  143,
#  42,
#  121,
#  12,
#  99,
#  10,
#  18,
#  143,
#  85,
#  180,
#  16,
#  44,
#  122,
#  73,
#  13,
#  133,
#  83,
#  68,
#  113,
#  18,
#  68,
#  56,
#  29,
#  18,
#  29,
#  17,
#  29,
#  77,
#  11,
#  134,
#  50,
#  79,
#  221,
#  50,
#  67,
#  65,
#  13,
#  93,
#  42,
#  75,
#  161,
#  115,
#  42,
#  153,
#  43,
#  100,
#  28,
#  16,
#  108,
#  56,
#  63,
#  58,
#  16,
#  40,
#  169,
#  41,
#  28,
#  41,
#  98,
#  135,
#  108,
#  10,
#  136,
#  153,
#  44,
#  23,
#  150,
#  107,
#  55,
#  24,
#  8,
#  48,
#  176,
#  51,
#  52,
#  101,
#  177,
#  9,
#  18,
#  23,
#  46,
#  101,
#  186,
#  150,
#  52,
#  241,
#  25,
#  24,
#  30,
#  29,
#  24,
#  10,
#  28,
#  74,
#  157,
#  27,
#  16,
#  17,
#  24,
#  84,
#  15,
#  9,
#  7,
#  24,
#  100,
#  81,
#  54,
#  29,
#  77,
#  99,
#  20,
#  94,
#  105,
#  72,
#  115,
#  27,
#  43,
#  18,
#  49,
#  193,
#  91,
#  41,
#  46,
#  19,
#  120,
#  43,
#  8,
#  24,
#  39,
#  23,
#  12,
#  107,
#  123,
#  42,
#  69,
#  185,
#  14,
#  8,
#  136,
#  39,
#  119,
#  40,
#  150,
#  21,
#  142,
#  145,
#  81,
#  90,
#  14,
#  93,
#  127,
#  22,
#  9,
#  77,
#  72,
#  9,
#  19,
#  62,
#  86,
#  146,
#  25,
#  25,
#  156,
#  41,
#  65,
#  109,
#  71,
#  36,
#  39,
#  147,
#  50,
#  17,
#  31,
#  81,
#  28,
#  114,
#  232,
#  8,
#  67,
#  38,
#  13,
#  41,
#  41,
#  13,
#  46,
#  40,
#  24,
#  8,
#  83,
#  35,
#  86,
#  67,
#  7,
#  28,
#  20,
#  28,
#  4,
#  24,
#  201,
#  16,
#  47,
#  13,
#  111,
#  21,
#  135,
#  138,
#  37,
#  21,
#  36,
#  77,
#  127,
#  53,
#  13,
#  39,
#  58,
#  83,
#  26,
#  46,
#  248,
#  39,
#  115,
#  83,
#  94,
#  28,
#  42,
#  7,
#  69,
#  85,
#  28,
#  42,
#  64,
#  66,
#  29,
#  40,
#  30,
#  35,
#  57,
#  29,
#  167,
#  100,
#  7,
#  10,
#  139,
#  105,
#  53,
#  27,
#  55,
#  16,
#  31,
#  142,
#  78,
#  56,
#  95,
#  57,
#  50,
#  97,
#  33,
#  5,
#  134,
#  31,
#  134,
#  46,
#  20,
#  7,
#  142,
#  26,
#  91,
#  99,
#  33,
#  16,
#  126,
#  198,
#  43,
#  60,
#  62,
#  47,
#  29,
#  59,
#  29,
#  78,
#  73,
#  23,
#  19,
#  21,
#  79,
#  134,
#  44,
#  194,
#  108,
#  49,
#  19,
#  33,
#  74,
#  51,
#  48,
#  60,
#  22,
#  77,
#  15,
#  103,
#  66,
#  105,
#  191,
#  185,
#  50,
#  58,
#  72,
#  63,
#  26,
#  102,
#  73,
#  122,
#  106,
#  9,
#  142,
#  ...]

# %%
data['sentence_len'] = sentence_len

# %%
data
# Out:
#         label                                             review  sentence_len
# 0           0  ﻿啊呀呀！要死啦！么么么！只穿外套就好了，我认为里面那件很多余啊周小伦喜歡 你各種 五角星的...            77
# 1           0  嗯……既然大姚通知了……那我也表示下收到……姚，你知道吗？假如外星人入侵地球，只要摧毁我们的...            96
# 2           0                                  风格不一样嘛，都喜欢！最喜欢哪张？            17
# 3           0  好呀，试试D .I .Y .去死皮面膜1.将燕麦片加水中浸泡6小时，加入木瓜牛奶搅拌。2.放...            94
# 4           0  张老师，谢谢侬的信任！粉丝多少无所谓重在质地近日发现一个现象——他加了你关注，你回加后，他立...            79
# ...       ...                                                ...           ...
# 361739      3                                         德国队就那样输了……            10
# 361740      3  人也一样,沒 钱沒 地位,谁会关注你?大庆和上海都是被人遗忘的角落，都是被遗弃的孩子。。。当...            88
# 361741      3                                             巴西要回家啦             6
# 361742      3  派啦！諗 咩吖 ！撐 呀！十五十六之而家已經 差不多十一月仲派唔派歌好呢?定係 出年先派呢?...            65
# 361743      3                         发觉呢个期末特别懒～死硬啦死硬啦，我要静心复习啊！！            26
#
# [361744 rows x 3 columns]

# %%
data.describe()
# Out:
#                label   sentence_len
# count  361744.000000  361744.000000
# mean        0.906854      69.480130
# std         1.143113      51.908534
# min         0.000000       1.000000
# 25%         0.000000      28.000000
# 50%         0.000000      54.000000
# 75%         2.000000     102.000000
# max         3.000000     419.000000

# %%
data['sentence_len'].hist()

# %%
from sklearn.model_selection import train_test_split

# %%
def data_split():
    data = pd.read_csv('simplifyweibo_4_moods.csv')
    content = data['review']
    label = data['label']
    train_content, test_content_t, train_label, test_label_t = train_test_split(content, label, test_size=0.2,
                                                                                random_state=100)
    test_t_len = len(test_label_t)
    test_len = test_t_len//2
    test_content = test_content_t[:test_len]
    test_label = test_label_t[:test_len]
    eval_content = test_content_t[test_len:]
    eval_label = test_label_t[test_len:]
    return train_content, train_label, test_content, test_label, eval_content, eval_label

# %%
train_content, train_label, test_content, test_label, eval_content, eval_label = data_split()

# %%
print(len(train_content), len(train_label), len(test_content), len(test_label), len(eval_content), len(eval_label))
# Out:
# 289395 289395 36174 36174 36175 36175
